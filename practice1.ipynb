# %%
import panda as pd
data = pd.read_csv("tips.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import panda as pd
#       2 data = pd.read_csv("tips.csv")
#
# ModuleNotFoundError: No module named 'panda'

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 9.9/9.9 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.6/12.6 MB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Ammar Shaikh\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
iimport panda as pd
data = pd.read_csv("tips.csv")
# Out:
#   Cell In[4], line 1
#     iimport panda as pd
#             ^
# SyntaxError: invalid syntax

# %%
import panda as pd
data = pd.read_csv("tips.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import panda as pd
#       2 data = pd.read_csv("tips.csv")
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
data = pd.read_csv("tips.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("tips.csv")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd
data = pd.read_csv("tips.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("tips.csv")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd
data = pd.read_csv("netflix_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("netflix_titles.csv")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd
data=pd.read_csv("netflix_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("netflix_titles.csv")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
import pandas as pd
data=pd.read_csv("netflix_titles.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("netflix_titles.csv")
#       3 data.head()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import pandas as pd
data=pd.read_csv(""C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
data.head()
# Out:
#   Cell In[11], line 2
#     data=pd.read_csv(""C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
data=pd.read_csv(C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
data.head()
# Out:
#   Cell In[12], line 2
#     data=pd.read_csv(C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data=pd.read_csv("C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
data.head()
# Out:
#   Cell In[13], line 2
#     data=pd.read_csv("C:\Users\Ammar Shaikh\OneDrive\Desktop\core java\netflix_titles.csv")
#                                                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\Ammar Shaikh\\OneDrive\\Desktop\\core java\\netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
pip install openpyxl
data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[1], line 1
#     pip install openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[2], line 1
#     data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
#                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
 install openpyxl
data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[3], line 1
#     install openpyxl
#     ^
# IndentationError: unexpected indent

# %%
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[4], line 2
#     excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
#                                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
#       2 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
#       3 excel_data.head()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
install openpyxl
data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[6], line 2
#     install openpyxl
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[7], line 2
#     data.to_excel("C:\Users\Ammar Shaikh\Downloads",sheet_name="sheet1",index=false)
#                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
      2 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
      3 excel_data.head()
# Out:
#   Cell In[8], line 2
#     2 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
#     ^
# IndentationError: unexpected indent

# %%
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
#       2 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
#       3 excel_data.head()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data=pd.read_excel
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
#       2 data=pd.read_excel
# ----> 3 data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
#       4 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
#       5 excel_data.head()
#
# AttributeError: 'function' object has no attribute 'to_excel'

# %%
import pandas as pd
data=pd.read_excel(""C:\\Users\\Ammar Shaikh\\Downloads")
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[11], line 2
#     data=pd.read_excel(""C:\\Users\\Ammar Shaikh\\Downloads")
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
data=pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads")
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads")
#       3 data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1",index=false)
#       4 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads",sheet_name="sheet1")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
# ...

# %%
import pandas as pd
data=pd.read_excel(""C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx")
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1")
excel_data.head()
# Out:
#   Cell In[13], line 2
#     data=pd.read_excel(""C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx")
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
data=pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx")
data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1",index=false)
excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1")
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx")
#       3 data.to_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1",index=false)
#       4 excel_data = pd.read_excel("C:\\Users\\Ammar Shaikh\\Downloads\\FINAL450.xlsx",sheet_name="sheet1")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# ...

# %%
pip install pandas openpyxl
import pandas as pd
df=pd.read_excel("FINAL450.xlsx")
print(df.head())
# Out:
#   Cell In[15], line 1
#     pip install pandas openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------ 250.9/250.9 kB 416.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_excel("FINAL450.xlsx")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_excel("FINAL450.xlsx")
#       3 print(df.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
# ...

# %%
pip install pandas openpyxl
import pandas as pd
df=pd.read_excel("FINAL450.xlsx")
print(df.head())
# Out:
#   Cell In[18], line 1
#     pip install pandas openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\Ammar Shaikh\\OneDrive\\Desktop\\data visualization_python\\FINAL450.xlsx")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_excel("C:\\Users\\Ammar Shaikh\\OneDrive\\Desktop\\data visualization_python\\FINAL450.xlsx")
#       3 print(df.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
# ...

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\Ammar Shaikh\\OneDrive\\Desktop\\data visualization_python\\FINAL450.xlsx")
print(df.head())
# Out:
#   Unnamed: 0                          Questions by Love Babbar:  \
# 0        NaN  Youtube Channel: https://www.youtube.com/chann...
# 1        NaN                                                NaN
# 2     Topic:                                          Problem:
# 3        NaN                                                NaN
# 4      Array                                  Reverse the array
#
#           Unnamed: 2 Unnamed: 3
# 0                NaN        NaN
# 1                NaN        NaN
# 2  Done [yes or no]         NaN
# 3                NaN        NaN
# 4                yes        NaN

# %%
'''import pandas as pd
df=pd.read_excel("FINAL450.xlsx")
print(df.head())'''
import pandas as pd
data=pd.read_excel("final450.xlsx")
print(data.head())
# Out:
#   Unnamed: 0                          Questions by Love Babbar:  \
# 0        NaN  Youtube Channel: https://www.youtube.com/chann...
# 1        NaN                                                NaN
# 2     Topic:                                          Problem:
# 3        NaN                                                NaN
# 4      Array                                  Reverse the array
#
#           Unnamed: 2 Unnamed: 3
# 0                NaN        NaN
# 1                NaN        NaN
# 2  Done [yes or no]         NaN
# 3                NaN        NaN
# 4                yes        NaN

# %%
import panda as pd
data=read_excel("cola")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import panda as pd
#       2 data=read_excel("cola")
#       3 print(data.head())
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
data=read_excel("cola")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 data=read_excel("cola")
#       3 print(data.head())
#
# NameError: name 'read_excel' is not defined

# %%
import panda as pd
data=pd.read_excel("cola")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import panda as pd
#       2 data=pd.read_excel("cola")
#       3 print(data.head())
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
data=pd.read_excel("cola")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_excel("cola")
#       3 print(data.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
# ...

# %%
import pandas as pd
data=pd.read_excel("cola.xlsx")
print(data.head())
# Out:
#    Data provided by SimFin              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                     NaN        NaN        NaN
# 1  Profit & Loss statement                     NaN        NaN        NaN
# 2                      NaN          in million USD     FY '09     FY '10
# 3                      NaN  NET OPERATING REVENUES      30990      35119
# 4                      NaN      Cost of goods sold      11088      12693
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2     FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3      46542      48017      46854      45998      44294      41863
# 4      18215      19053      18421      17889      17482      16465
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2      FY '17      FY '18
# ...

# %%
excel_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 excel_data.head()
#
# NameError: name 'excel_data' is not defined

# %%
pip install sqlite3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import panda as pd
conn=sqlite3.connect(":memory")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import panda as pd
#       2 conn=sqlite3.connect(":memory")
#       3 data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
conn=sqlite3.connect(":memory")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 conn=sqlite3.connect(":memory")
#       3 data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
#
# NameError: name 'sqlite3' is not defined

# %%
pip install sqlite3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sqlite3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
conn=sqlite3.connect(":memory")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 conn=sqlite3.connect(":memory")
#       3 data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
#
# NameError: name 'sqlite3' is not defined

# %%
python.exe -m pip install
# Out:
#   Cell In[3], line 1
#     python.exe -m pip install
#                   ^
# SyntaxError: invalid syntax

# %%
import panda as pd
import sqlite3
conn=sqlite3.connect(":memory")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import panda as pd
#       2 import sqlite3
#       3 conn=sqlite3.connect(":memory")
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect(":memory")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import sqlite3
# ----> 3 conn=sqlite3.connect(":memory")
#       4 data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
#
# OperationalError: unable to open database file

# %%
import mysql.connector;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mysql.connector;
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import pandas as pd;
import mysql.connector;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd;
# ----> 2 import mysql.connector;
#
# ModuleNotFoundError: No module named 'mysql'

# %%
conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh")
#
# NameError: name 'mysql' is not defined

# %%
import pandas as pd;
import mysql.connector;
conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh");
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd;
# ----> 2 import mysql.connector;
#       3 conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh");
#
# ModuleNotFoundError: No module named 'mysql'

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 16.5/16.5 MB 1.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd;
import mysql.connector;
conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh");

# %%
conn=mysql.connector.connect(host="localhost",user="root",password="bca1234",database="shaikh");

# %%
query='select * from movi_info'
df=pd.read_sql(query,conn)
df
# Out:
# C:\Users\Ammar Shaikh\AppData\Local\Temp\ipykernel_5888\2541637802.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#    id movie_Type              title       country        director
# 0  11   thriller  dickJohnsonIsDead  Unitedstates  KirstenJohnson
# 1  12   thriller           mccmafia        london            john
# 2  13    romance           saiyaara         india           rohit

# %%
df=pd.read_sql(query,conn)
df
# Out:
# C:\Users\Ammar Shaikh\AppData\Local\Temp\ipykernel_5888\2545783912.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#    id movie_Type              title       country        director
# 0  11   thriller  dickJohnsonIsDead  Unitedstates  KirstenJohnson
# 1  12   thriller           mccmafia        london            john
# 2  13    romance           saiyaara         india           rohit

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("shaikh")
data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 import sqlite3
#       3 conn=sqlite3.connect("shaikh")
# ----> 4 data.sql("sql-murder-mystery",conn,index=false,if_exists="replace")
#
# NameError: name 'data' is not defined

# %%
conn = sqlite3.connect("shaikh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 conn = sqlite3.connect("shaikh")
#
# NameError: name 'sqlite3' is not defined

# %%
pip install sqlite3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D0C514D3D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlite3/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D0C514DED0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlite3/
# ...

# %%
import sqlite3
conn=sqlite3.connect("shaikh")

# %%
data.to_sql('movi_name',conn,index=false,if_exists='replace')
sql_data=pd.read_sql(select* from movi_info,conn)
sql_data.head()
# Out:
#   Cell In[4], line 2
#     sql_data=pd.read_sql(select* from movi_info,conn)
#                                  ^
# SyntaxError: invalid syntax

# %%
data.to_sql('movi_name',conn,index=false,if_exists='replace')
sql_data=pd.read_sql(select * from movi_info,conn)
sql_data.head()
# Out:
#   Cell In[5], line 2
#     sql_data=pd.read_sql(select * from movi_info,conn)
#                                   ^
# SyntaxError: invalid syntax

# %%
data.to_sql('movi_name',conn,index=false,if_exists='replace')
sql_data=pd.read_sql("select* from movi_info,conn")
sql_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data.to_sql('movi_name',conn,index=false,if_exists='replace')
#       2 sql_data=pd.read_sql("select* from movi_info,conn")
#       3 sql_data.head()
#
# NameError: name 'data' is not defined

# %%
pip install sqlalchemy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000017510109E50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001751010A950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlalchemy/
# ...

# %%
data.to_sql('movi_name',conn,index=false,if_exists='replace')
sql_data=pd.read_sql("select * from movi_info",conn)
sql_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.to_sql('movi_name',conn,index=false,if_exists='replace')
#       2 sql_data=pd.read_sql("select * from movi_info",conn)
#       3 sql_data.head()
#
# NameError: name 'data' is not defined

# %%
data=pd.read_sql("select * from movi_info",conn)
data.to_sql('movi_info',conn,index=False,if_exists='replace')
sql_data = pd.read_sql("select * from movi_info",conn)
sql_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data=pd.read_sql("select * from movi_info",conn)
#       2 data.to_sql('movi_info',conn,index=False,if_exists='replace')
#       3 sql_data = pd.read_sql("select * from movi_info",conn)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
data=pd.read_sql("select * from movi_info",conn)
data.to_sql('movi_info',conn,index=False,if_exists='replace')
sql_data = pd.read_sql("select * from movi_info",conn)
sql_data.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: movi_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_sql("select * from movi_info",conn)
#       3 data.to_sql('movi_info',conn,index=False,if_exists='replace')
#       4 sql_data = pd.read_sql("select * from movi_info",conn)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
import pandas as dp
import sqlite3
connn=sqlite3.connect("shaikh.db")
dat=dp.read_sql("select * from movi_info",connn)
dat.to_sql('movi_info',conn,index=False,if_exists='replace')
sql_data1 = pd.read_sql("select * from movi_info",connn)
sql_data1.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: movi_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[12], line 4
#       2 import sqlite3
#       3 connn=sqlite3.connect("shaikh.db")
# ----> 4 dat=dp.read_sql("select * from movi_info",connn)
#       5 dat.to_sql('movi_info',conn,index=False,if_exists='replace')
#       6 sql_data1 = pd.read_sql("select * from movi_info",connn)
#
# ...

# %%
import pandas as dp
import sqlite3
connn=sqlite3.connect("shaikh")
dat=dp.read_sql("select * from movi_info",connn)
dat.to_sql('movi_info',conn,index=False,if_exists='replace')
sql_data1 = pd.read_sql("select * from movi_info",connn)
sql_data1.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: movi_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[13], line 4
#       2 import sqlite3
#       3 connn=sqlite3.connect("shaikh")
# ----> 4 dat=dp.read_sql("select * from movi_info",connn)
#       5 dat.to_sql('movi_info',conn,index=False,if_exists='replace')
#       6 sql_data1 = pd.read_sql("select * from movi_info",connn)
#
# ...

# %%
import panda as pd
pd.read_sql("select name from sqlite_master where type ='movi_info';",connn)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import panda as pd
#       2 pd.read_sql("select name from sqlite_master where type ='movi_info';",connn)
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
pd.read_sql("select name from sqlite_master where type ='movi_info';",connn)
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
print(connn)

# %%
connn=sqlite3.connect("shaikh.db")
print(connn)

# %%
import pandas as pd
pd.read_sql("select name from sqlite_master where type ='table';",connn)
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
import pandas as dp
import sqlite3
connn=sqlite3.connect("shaikh.db")
dp.read_sql("select name from sqlite_master where type ='table';",connn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: movi_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[19], line 4
#       2 import sqlite3
#       3 connn=sqlite3.connect("shaikh.db")
# ----> 4 dat=dp.read_sql("select * from movi_info",connn)
#       5 dat.to_sql('movi_info',conn,index=False,if_exists='replace')
#       6 sql_data1 = pd.read_sql("select * from movi_info",connn)
#
# ...

# %%
import pandas as dp
import sqlite3
connn=sqlite3.connect("shaikh.db")
dp.read_sql("select name from sqlite_master where type ='table';",connn)
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# import mysql.connector
# conn= mysql.connector.connect(
# host="localhost",
# user="root",
# password="bca1234",
# database="shaikh"
# )
# cursor = conn.cursor()
# cursor.execute();

# %%
quer="select *  from movi_info")
df=pd.read_sql(quer,conn)
print(df.head())
# Out:
#   Cell In[22], line 1
#     quer="select *  from movi_info")
#                                    ^
# SyntaxError: unmatched ')'

# %%
quer=("select *  from movi_info")
df=pd.read_sql(quer,conn)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: movi_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[23], line 2
#       1 quer=("select *  from movi_info")
# ----> 2 df=pd.read_sql(quer,conn)
#       3 print(df.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# ...

# %%
import mysql.connector
conn= mysql.connector.connect(
host="localhost",
user="root",
password="bca1234",
database="shaikh"
)
quer=("select *  from movi_info")
df=pd.read_sql(quer,conn)
df.head()
# Out:
# C:\Users\Ammar Shaikh\AppData\Local\Temp\ipykernel_12000\3630995720.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(quer,conn)
#    id movie_Type              title       country        director
# 0  11   thriller  dickJohnsonIsDead  Unitedstates  KirstenJohnson
# 1  12   thriller           mccmafia        london            john
# 2  13    romance           saiyaara         india           rohit

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000149A5D21850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000149A5D22450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sqlalchemy/
# ...

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine 
engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
quer=("select *  from movi_info")
df=pd.read_sql(quer,conn)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mysql.connector
#       2 import pandas as pd
# ----> 3 from sqlalchemy import create_engine
#       4 engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
#       5 quer=("select *  from movi_info")
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
import mysql.connector
conn= mysql.connector.connect(
host="localhost",
user="root",
password="bca1234",
database="shaikh"
)
quer=("select *  from movi_info")
df=pd.read_sql(quer,conn)
df.head()
# Out:
# C:\Users\Ammar Shaikh\AppData\Local\Temp\ipykernel_10224\3630995720.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(quer,conn)
#    id movie_Type              title       country        director
# 0  11   thriller  dickJohnsonIsDead  Unitedstates  KirstenJohnson
# 1  12   thriller           mccmafia        london            john
# 2  13    romance           saiyaara         india           rohit

# %%
    1 import mysql.connector
      2 import pandas as pd
----> 3 from sqlalchemy import create_engine 
      4 engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
      5 quer=("select *  from movi_info")
# Out:
#   Cell In[3], line 1
#     1 import mysql.connector
#     ^
# IndentationError: unexpected indent

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine 
engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
quer=("select *  from movi_info")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import mysql.connector
#       2 import pandas as pd
# ----> 3 from sqlalchemy import create_engine
#       4 engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
#       5 quer=("select *  from movi_info")
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine 
engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
quer=("select *  from movi_info")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mysql.connector
#       2 import pandas as pd
# ----> 3 from sqlalchemy import create_engine
#       4 engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
#       5 quer=("select *  from movi_info")
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 2.1/2.1 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 226.5/226.5 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine 
engine = create_engine('mysql+mysqlconnector://root:bca1234@localhost/shaikh')
quer=("select *  from movi_info")
df=pd.read_sql(quer,engine)

# %%
df
# Out:
#    id movie_Type              title       country        director
# 0  11   thriller  dickJohnsonIsDead  Unitedstates  KirstenJohnson
# 1  12   thriller           mccmafia        london            john
# 2  13    romance           saiyaara         india           rohit

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests

# %%
url="https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
data=response.json()
print(data[0])
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
df_user = pd.dataframe(data)
df_user.head();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_user = pd.dataframe(data)
#       2 df_user.head();
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
df_user = pd.DataFrame(data)
df_user.head(df_user);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 df_user = pd.DataFrame(data)
# ----> 2 df_user.head(df_user);
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5761, in NDFrame.head(self, n)
#    5674 @final
#    5675 def head(self, n: int = 5) -> Self:
#    5676     """
#    5677     Return the first `n` rows.
#    5678
#    (...)   5759     5     parrot
#    5760     """
# -> 5761     return self.iloc[:n].copy()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
url="https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
data=response.json()
print(data[0])
df_user = pd.dataframe(data)
df_user.head();
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       3 data=response.json()
#       4 print(data[0])
# ----> 5 df_user = pd.dataframe(data)
#       6 df_user.head();
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
import pandas as pd
import requests
url="https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
data=response.json()
print(data[0])
df_user = pd.DataFrame(data)
df_user.head();
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
import pandas as pd
import requests
url="https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
data=response.json()
print(data[0])
df_user = pd.DataFrame(data)
df_user.head();
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
